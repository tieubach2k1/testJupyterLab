# %%
# Importing the libraries
import numpy as np
import pandas as pd

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/int3405-sentiment-analysis-problem/test.csv
# /kaggle/input/int3405-sentiment-analysis-problem/full_train.csv

# %%
# !wget "https://thiaisotajppub.s3-ap-northeast-1.amazonaws.com/publicfiles/baomoi.window2.vn.model.bin.gz"
# Out:
# --2022-12-13 09:41:48--  https://thiaisotajppub.s3-ap-northeast-1.amazonaws.com/publicfiles/baomoi.window2.vn.model.bin.gz
# Resolving thiaisotajppub.s3-ap-northeast-1.amazonaws.com (thiaisotajppub.s3-ap-northeast-1.amazonaws.com)... 52.219.136.115, 52.219.197.118, 52.219.196.50, ...
# Connecting to thiaisotajppub.s3-ap-northeast-1.amazonaws.com (thiaisotajppub.s3-ap-northeast-1.amazonaws.com)|52.219.136.115|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 494402382 (471M) [application/x-gzip]
# Saving to: ‘baomoi.window2.vn.model.bin.gz’
#
# baomoi.window2.vn.m 100%[===================>] 471.50M  30.9MB/s    in 16s
#
# 2022-12-13 09:42:05 (29.2 MB/s) - ‘baomoi.window2.vn.model.bin.gz’ saved [494402382/494402382]

# %%
from gensim.models import KeyedVectors
from gensim import models

word2vec_path = '/kaggle/working/baomoi.window2.vn.model.bin.gz'
w2v_model = models.KeyedVectors.load_word2vec_format(word2vec_path, binary=True)

# %%
vector = w2v_model['y']
vector.shape
# Out:
# (300,)

# %%
# Importing the dataset
trainData = pd.read_csv("/kaggle/input/int3405-sentiment-analysis-problem/full_train.csv")
testData = pd.read_csv("/kaggle/input/int3405-sentiment-analysis-problem/test.csv")
print("Train shape : ",trainData.shape)
print("Test shape : ",testData.shape)
# Out:
# Train shape :  (9073, 6)
# Test shape :  (5103, 5)

# %%
trainData = trainData.dropna()
trainData
# Out:
#      Unnamed: 0     RevId      UserId  \
# 0             0   3839333  10106093.0
# 1             1   2824877    786914.0
# 2             2   9816702  22467889.0
# 3             3   2684585   1889449.0
# 4             4   2737987   8839942.0
# ...         ...       ...         ...
# 9068       9066  11236510  23044142.0
# 9069       9067   1831645  10117823.0
# 9070       9068   2155495  11636069.0
# 9071       9069   7357032  12208284.0
# 9072       9070   2406407  13541782.0
#
#                                                 Comment  \
# 0     Xôi dẻo, đồ ăn đậm vị. Hộp xôi được lót lá trô...
# 1     Gọi ship 1 xuất cari gà bánh naan và 3 miếng g...
# 2     Thời tiết lạnh như này, cả nhà rủ nhau đến leg...
# 3     Em có đọc review thấy mng bảo trà sữa nướng đề...
# 4     Đồ ăn rất ngon, nhà hàng cũng rất đẹp, tất cả ...
# ...                                                 ...
# 9068  Thực sự mà nói thấy mọi người đánh giá nhiều q...
# 9069  👉👉👉LẨU THÁI TÔMYUM\n👉👉Đc: 19 Lò Đúc-HBT-HN\n👉T...
# 9070  Ngay từ lúc đầu tiên bước vào nhà hàng đã được...
# 9071  Đặt ăn thử mà thấy ngón cá...! 🤩 sẽ còn ủn hộ ...
# 9072  Nay xem bóng đá VN lười nấu cơm. Nghe các bạn ...
#
#                                              image_urls  Rating
# 0     ['https://images.foody.vn/res/g97/966781/s800/...     1.0
# 1     ['https://images.foody.vn/res/g69/688413/s800/...     0.0
# 2     ['https://images.foody.vn/res/g72/715078/s800/...     1.0
# 3     ['https://images.foody.vn/res/g90/895545/s800/...     0.0
# 4     ['https://images.foody.vn/res/g4/30186/s800/fo...     1.0
# ...                                                 ...     ...
# 9068  ['https://images.foody.vn/res/g94/930433/s800/...     1.0
# 9069  ['https://images.foody.vn/res/g16/150633/s800/...     1.0
# 9070  ['https://images.foody.vn/res/g74/736118/s800/...     1.0
# 9071  ['https://images.foody.vn/res/g104/1036659/s80...     1.0
# 9072  ['https://images.foody.vn/res/g75/745511/s800/...     1.0
#
# [9070 rows x 6 columns]

# %%
max_features = 500000
max_len = 30 
embed_size = 300

def clean_special_chars(text):
    punct = "/-'?!.,#$%\'()*+-/:;<=>@[\\]^_`{|}~" + '""“”’' + '∞θ÷α•à−β∅³π‘₹´°£€\×™√²—–&'
    
    punct_mapping = {
        "‘": "'", "´": "'", "°": "", "vnd": "đồng", "—": "-", "–": "-", "’": "'", "_": "-", "`": "'", '“': '"', 
        '”': '"', '“': '"', '•': '.', '−': '-'
    }
    
    for p in punct_mapping:
        text = text.replace(p, punct_mapping[p])
    
    for p in punct:
        text = text.replace(p, f' {p} ')
    
    return text

from sklearn.model_selection import train_test_split
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
def dataHandling(trainData, testData, maxfeatures, maxlen):
    Traindf, Valdf = train_test_split(trainData, test_size=0.1, random_state=2018)
    
    Train_y = Traindf['Rating'].values
    Val_y = Valdf['Rating'].values
    
    Train_X = Traindf['Comment'].astype(str).apply(lambda x: x.lower())
    Train_X = Train_X.apply(lambda x: clean_special_chars(x))
    
    Val_X = Valdf['Comment'].astype(str).apply(lambda x: x.lower())
    Val_X = Val_X.apply(lambda x: clean_special_chars(x))

    Test_X = testData['Comment'].astype(str).apply(lambda x: x.lower())
    Test_X = Test_X.apply(lambda x: clean_special_chars(x))

    tokenizer = Tokenizer(num_words = max_features)
    tokenizer.fit_on_texts(list(Train_X))
    Train_X = tokenizer.texts_to_sequences(Train_X)
    Val_X = tokenizer.texts_to_sequences(Val_X)
    Test_X = tokenizer.texts_to_sequences(Test_X)

    Train_X = pad_sequences(Train_X, maxlen=maxlen)
    Val_X = pad_sequences(Val_X, maxlen=maxlen)
    Test_X = pad_sequences(Test_X, maxlen=maxlen)

    return Train_X, Train_y, Test_X, Val_X, Val_y, tokenizer.word_index

Train_X, Train_y, Test_X, Val_X, Val_y, WordIndex = dataHandling(trainData, testData, max_features, max_len)

# %%
WordIndex
# Out:
# {'à': 1,
#  'ăn': 2,
#  'mình': 3,
#  'l': 4,
#  'v': 5,
#  'có': 6,
#  'quán': 7,
#  'không': 8,
#  'n': 9,
#  'thì': 10,
#  'm': 11,
#  'ngon': 12,
#  'cũng': 13,
#  'nên': 14,
#  'ở': 15,
#  'rất': 16,
#  'nhưng': 17,
#  'o': 18,
#  '1': 19,
#  'y': 20,
#  'đồ': 21,
#  'đây': 22,
#  'khá': 23,
#  'ng': 24,
#  'thấy': 25,
#  'được': 26,
#  'lại': 27,
#  'h': 28,
#  'bánh': 29,
#  'vị': 30,
#  'giá': 31,
#  'nhiều': 32,
#  'với': 33,
#  'cho': 34,
#  'như': 35,
#  'gọi': 36,
#  'cả': 37,
#  'nh': 38,
#  'món': 39,
#  'sẽ': 40,
#  'hơi': 41,
#  'i': 42,
#  'đi': 43,
#  'ko': 44,
#  'còn': 45,
#  'các': 46,
#  'nhân': 47,
#  'nước': 48,
#  'phải': 49,
#  'đến': 50,
#  '2': 51,
#  'lần': 52,
#  'quá': 53,
#  'thịt': 54,
#  'ra': 55,
#  'viên': 56,
#  'của': 57,
#  'bạn': 58,
#  'luôn': 59,
#  'uống': 60,
#  'lắm': 61,
#  'để': 62,
#  'k': 63,
#  'vừa': 64,
#  'vì': 65,
#  'một': 66,
#  'trong': 67,
#  'g': 68,
#  'thích': 69,
#  'cái': 70,
#  'người': 71,
#  'tr': 72,
#  'chỉ': 73,
#  'hơn': 74,
#  'nữa': 75,
#  'về': 76,
#  'rồi': 77,
#  'thử': 78,
#  'gian': 79,
#  'ngọt': 80,
#  'thêm': 81,
#  'bị': 82,
#  'mới': 83,
#  'vụ': 84,
#  'nói': 85,
#  'hay': 86,
#  'đã': 87,
#  'gì': 88,
#  'thơm': 89,
#  'cơm': 90,
#  'b': 91,
#  'ngồi': 92,
#  'hợp': 93,
#  'vẫn': 94,
#  'phục': 95,
#  'to': 96,
#  'khách': 97,
#  'hết': 98,
#  'đầu': 99,
#  'nhất': 100,
#  'hôm': 101,
#  'chỗ': 102,
#  'đặt': 103,
#  'khác': 104,
#  'bò': 105,
#  'thôi': 106,
#  'chất': 107,
#  'khi': 108,
#  'chua': 109,
#  'bún': 110,
#  'tình': 111,
#  'ý': 112,
#  'lượng': 113,
#  'bát': 114,
#  'quay': 115,
#  'từ': 116,
#  'sốt': 117,
#  '3': 118,
#  'chắc': 119,
#  'qua': 120,
#  'lúc': 121,
#  'sữa': 122,
#  'đặc': 123,
#  'đẹp': 124,
#  'chung': 125,
#  'đông': 126,
#  'thế': 127,
#  'trên': 128,
#  'nướng': 129,
#  'sự': 130,
#  'chưa': 131,
#  'nhìn': 132,
#  'ngo': 133,
#  'điểm': 134,
#  'cảm': 135,
#  'ổn': 136,
#  'mấy': 137,
#  'đầy': 138,
#  'đc': 139,
#  'chủ': 140,
#  'nhiệt': 141,
#  'loại': 142,
#  'thể': 143,
#  'lẩu': 144,
#  'dễ': 145,
#  'cốc': 146,
#  'đó': 147,
#  'bên': 148,
#  'mì': 149,
#  'ít': 150,
#  'kiểu': 151,
#  'chả': 152,
#  'nhanh': 153,
#  'sạch': 154,
#  'mua': 155,
#  'lên': 156,
#  'đường': 157,
#  'rau': 158,
#  'sau': 159,
#  'suất': 160,
#  'miệng': 161,
#  'nhỏ': 162,
#  'thường': 163,
#  'miếng': 164,
#  'nhận': 165,
#  'mềm': 166,
#  'nhé': 167,
#  'biết': 168,
#  'cá': 169,
#  'kem': 170,
#  'cùng': 171,
#  'ngay': 172,
#  'd': 173,
#  'gần': 174,
#  'ạ': 175,
#  'chứ': 176,
#  'tìm': 177,
#  'đủ': 178,
#  'rẻ': 179,
#  'bình': 180,
#  'đ': 181,
#  'tầng': 182,
#  'tươi': 183,
#  'nay': 184,
#  'giờ': 185,
#  'giòn': 186,
#  'mỗi': 187,
#  'đều': 188,
#  'nóng': 189,
#  'nếu': 190,
#  'biệt': 191,
#  'chấm': 192,
#  'lâu': 193,
#  'đâu': 194,
#  'con': 195,
#  'cực': 196,
#  'thật': 197,
#  'bán': 198,
#  'những': 199,
#  'dùng': 200,
#  'trí': 201,
#  'thái': 202,
#  'bao': 203,
#  'đúng': 204,
#  'mùi': 205,
#  'tiền': 206,
#  'trước': 207,
#  'c': 208,
#  'ok': 209,
#  'sao': 210,
#  'chè': 211,
#  'rộng': 212,
#  'cay': 213,
#  'no': 214,
#  'bảo': 215,
#  'siêu': 216,
#  'nem': 217,
#  'xong': 218,
#  'trứng': 219,
#  'đậm': 220,
#  'vậy': 221,
#  'chút': 222,
#  'kèm': 223,
#  'đậu': 224,
#  'mọi': 225,
#  'cơ': 226,
#  'em': 227,
#  'mát': 228,
#  'so': 229,
#  'thực': 230,
#  'chọn': 231,
#  'đá': 232,
#  'hình': 233,
#  'nó': 234,
#  'phần': 235,
#  'cứ': 236,
#  'xe': 237,
#  'lòng': 238,
#  'ship': 239,
#  'do': 240,
#  'chị': 241,
#  'mỳ': 242,
#  'theo': 243,
#  'order': 244,
#  'ấy': 245,
#  'đĩa': 246,
#  'khô': 247,
#  'tầm': 248,
#  'thứ': 249,
#  'ảnh': 250,
#  'sinh': 251,
#  'quả': 252,
#  'muốn': 253,
#  'thân': 254,
#  'mang': 255,
#  'độ': 256,
#  'thanh': 257,
#  'tuy': 258,
#  'bé': 259,
#  'nhạt': 260,
#  'phố': 261,
#  'nhiên': 262,
#  '4': 263,
#  'tôm': 264,
#  'tối': 265,
#  'chiên': 266,
#  'ho': 267,
#  'ưng': 268,
#  'lý': 269,
#  'đắt': 270,
#  'nằm': 271,
#  'menu': 272,
#  'cô': 273,
#  'phở': 274,
#  'trộn': 275,
#  'đa': 276,
#  'thiện': 277,
#  'đặn': 278,
#  'hoa': 279,
#  'ai': 280,
#  'anh': 281,
#  'tới': 282,
#  'châu': 283,
#  'tiên': 284,
#  'mặt': 285,
#  'tại': 286,
#  'bằng': 287,
#  'vọng': 288,
#  'nha': 289,
#  'chân': 290,
#  'mở': 291,
#  'khoai': 292,
#  'cách': 293,
#  'tốt': 294,
#  'hộp': 295,
#  'dù': 296,
#  'cửa': 297,
#  'trân': 298,
#  'giác': 299,
#  'đáng': 300,
#  'vs': 301,
#  'riêng': 302,
#  '10': 303,
#  'hè': 304,
#  'khó': 305,
#  'đấy': 306,
#  'rán': 307,
#  'cafe': 308,
#  'x': 309,
#  'tuyệt': 310,
#  'giảm': 311,
#  'lạ': 312,
#  'hỏi': 313,
#  'xem': 314,
#  'hộ': 315,
#  '5': 316,
#  'nhau': 317,
#  'ốc': 318,
#  'mặn': 319,
#  'thoáng': 320,
#  'trưa': 321,
#  'nghĩ': 322,
#  'điều': 323,
#  'mai': 324,
#  'cao': 325,
#  'ủng': 326,
#  'tiếp': 327,
#  'th': 328,
#  'bọn': 329,
#  'vẻ': 330,
#  'nơi': 331,
#  'ngậy': 332,
#  'nổi': 333,
#  'tính': 334,
#  'đang': 335,
#  'tượng': 336,
#  'sáng': 337,
#  'công': 338,
#  'định': 339,
#  'u': 340,
#  'xôi': 341,
#  'thất': 342,
#  'dai': 343,
#  'cuối': 344,
#  'dừa': 345,
#  'cuốn': 346,
#  'đen': 347,
#  'giống': 348,
#  'sang': 349,
#  'ngõ': 350,
#  'khu': 351,
#  'mái': 352,
#  'số': 353,
#  't': 354,
#  'mất': 355,
#  'sắc': 356,
#  'sườn': 357,
#  'mắt': 358,
#  'buổi': 359,
#  'trời': 360,
#  'trung': 361,
#  'thoải': 362,
#  'xinh': 363,
#  'ấn': 364,
#  'rõ': 365,
#  'chán': 366,
#  'đứa': 367,
#  'chụp': 368,
#  'gia': 369,
#  'cháo': 370,
#  'lạnh': 371,
#  'nhớ': 372,
#  'tự': 373,
#  'hai': 374,
#  'tạm': 375,
#  'giao': 376,
#  'nội': 377,
#  'xíu': 378,
#  'review': 379,
#  'xanh': 380,
#  'muối': 381,
#  'vô': 382,
#  'đối': 383,
#  'địa': 384,
#  'nhẹ': 385,
#  'ngấy': 386,
#  'rãi': 387,
#  'ghé': 388,
#  'yên': 389,
#  'tâm': 390,
#  'mỡ': 391,
#  'cần': 392,
#  'hoặc': 393,
#  'thức': 394,
#  'vỉa': 395,
#  'canh': 396,
#  'chuẩn': 397,
#  'vui': 398,
#  'tí': 399,
#  'sản': 400,
#  'từng': 401,
#  'sống': 402,
#  'tương': 403,
#  'yêu': 404,
#  'thèm': 405,
#  'dạng': 406,
#  'tây': 407,
#  'nghe': 408,
#  'chanh': 409,
#  'phô': 410,
#  'béo': 411,
#  'mắm': 412,
#  'đơn': 413,
#  'trang': 414,
#  'now': 415,
#  'bữa': 416,
#  'view': 417,
#  'bỏ': 418,
#  'tận': 419,
#  'hải': 420,
#  'dưa': 421,
#  'r': 422,
#  'salad': 423,
#  'phòng': 424,
#  'cua': 425,
#  'phù': 426,
#  'cộng': 427,
#  'mãi': 428,
#  'đánh': 429,
#  'gói': 430,
#  'rang': 431,
#  'trừ': 432,
#  'đổi': 433,
#  'quan': 434,
#  'sở': 435,
#  'trông': 436,
#  '30k': 437,
#  'hồi': 438,
#  'tưởng': 439,
#  'khẩu': 440,
#  'hiểu': 441,
#  'ấm': 442,
#  'nhật': 443,
#  'ướp': 444,
#  'xuất': 445,
#  'ớt': 446,
#  '😂': 447,
#  'việc': 448,
#  'đóng': 449,
#  'tráng': 450,
#  'bột': 451,
#  'dẻo': 452,
#  'tiếng': 453,
#  'bụng': 454,
#  'chịu': 455,
#  'phong': 456,
#  'chính': 457,
#  'đợi': 458,
#  'kì': 459,
#  'lịch': 460,
#  'cầu': 461,
#  'thạch': 462,
#  'chờ': 463,
#  'giò': 464,
#  'nhẹn': 465,
#  'bơ': 466,
#  'set': 467,
#  'tay': 468,
#  'chiều': 469,
#  'tệ': 470,
#  'tổng': 471,
#  'khoảng': 472,
#  'hương': 473,
#  'chắn': 474,
#  'nguyên': 475,
#  'xin': 476,
#  'tôi': 477,
#  'tiện': 478,
#  'cốt': 479,
#  'cổ': 480,
#  'pha': 481,
#  'thương': 482,
#  'túi': 483,
#  'pizza': 484,
#  'quen': 485,
#  'miến': 486,
#  'dẫn': 487,
#  'topping': 488,
#  'tư': 489,
#  'tuần': 490,
#  'cạnh': 491,
#  'tên': 492,
#  'lấy': 493,
#  'nấm': 494,
#  'vời': 495,
#  'học': 496,
#  'năm': 497,
#  'chi': 498,
#  'dân': 499,
#  'vỏ': 500,
#  'đáo': 501,
#  'kết': 502,
#  'quên': 503,
#  'đồng': 504,
#  'combo': 505,
#  'tội': 506,
#  'hề': 507,
#  'dưới': 508,
#  'hạt': 509,
#  'chẳng': 510,
#  'mức': 511,
#  '25k': 512,
#  'phê': 513,
#  'buffet': 514,
#  'xo': 515,
#  'thời': 516,
#  'kinh': 517,
#  'chu': 518,
#  'hẳn': 519,
#  'dầu': 520,
#  'lớn': 521,
#  'tĩnh': 522,
#  'tất': 523,
#  '6': 524,
#  'gồm': 525,
#  'hấp': 526,
#  'ghế': 527,
#  'hồ': 528,
#  'bắt': 529,
#  '35k': 530,
#  'giấy': 531,
#  'trọng': 532,
#  'dịp': 533,
#  'cứng': 534,
#  '40k': 535,
#  'trường': 536,
#  'cải': 537,
#  'chuyên': 538,
#  'nhạc': 539,
#  's': 540,
#  'dịch': 541,
#  'thay': 542,
#  'mong': 543,
#  'mặc': 544,
#  'ba': 545,
#  'nồi': 546,
#  'mê': 547,
#  'lớp': 548,
#  'nv': 549,
#  'kia': 550,
#  'chê': 551,
#  'vệ': 552,
#  'foody': 553,
#  'cheese': 554,
#  'chú': 555,
#  '50k': 556,
#  'văn': 557,
#  'chế': 558,
#  'bia': 559,
#  'xa': 560,
#  'chuyện': 561,
#  'mùa': 562,
#  'kim': 563,
#  'tẩm': 564,
#  'khen': 565,
#  'lựa': 566,
#  'phí': 567,
#  'lá': 568,
#  'tiêu': 569,
#  '20k': 570,
#  'tặng': 571,
#  'cây': 572,
#  'lẽ': 573,
#  'bác': 574,
#  'phết': 575,
#  'việt': 576,
#  'dã': 577,
#  'ngờ': 578,
#  'tập': 579,
#  'đưa': 580,
#  'nhóm': 581,
#  'cẩn': 582,
#  'tô': 583,
#  'hiện': 584,
#  'chơi': 585,
#  'bất': 586,
#  'shop': 587,
#  'bếp': 588,
#  'cháy': 589,
#  'thận': 590,
#  'thiếu': 591,
#  'trắng': 592,
#  'nghiệp': 593,
#  'cẩm': 594,
#  'dc': 595,
#  'nghiện': 596,
#  'e': 597,
#  'nửa': 598,
#  'diện': 599,
#  'the': 600,
#  'size': 601,
#  'tiết': 602,
#  'trần': 603,
#  'hổi': 604,
#  'nấu': 605,
#  'giới': 606,
#  'vịt': 607,
#  '10k': 608,
#  'họ': 609,
#  'sợ': 610,
#  'man': 611,
#  'quẩy': 612,
#  'liên': 613,
#  'í': 614,
#  'trình': 615,
#  'thưởng': 616,
#  "'": 617,
#  'matcha': 618,
#  'duy': 619,
#  'xuống': 620,
#  'nam': 621,
#  'đói': 622,
#  'a': 623,
#  'may': 624,
#  'decor': 625,
#  'nghiệm': 626,
#  'quất': 627,
#  'bè': 628,
#  'sợi': 629,
#  'pate': 630,
#  'chậm': 631,
#  'nộm': 632,
#  'yếu': 633,
#  'cx': 634,
#  'đỡ': 635,
#  'giữa': 636,
#  'bản': 637,
#  'trả': 638,
#  'hồng': 639,
#  '8': 640,
#  '\r': 641,
#  'ép': 642,
#  'bộ': 643,
#  'trẻ': 644,
#  'tết': 645,
#  'nc': 646,
#  'chăng': 647,
#  'đình': 648,
#  'kỳ': 649,
#  'hội': 650,
#  'thập': 651,
#  'mưa': 652,
#  'mực': 653,
#  'góc': 654,
#  'kể': 655,
#  '7': 656,
#  '30': 657,
#  'mỏng': 658,
#  'chín': 659,
#  'xúc': 660,
#  'đỏ': 661,
#  'mẹ': 662,
#  'chật': 663,
#  'tục': 664,
#  'nè': 665,
#  'vấn': 666,
#  'xiên': 667,
#  'kém': 668,
#  'đại': 669,
#  'khuyến': 670,
#  'biển': 671,
#  'ông': 672,
#  'lươn': 673,
#  'ban': 674,
#  'nguội': 675,
#  'lời': 676,
#  'ơi': 677,
#  'căng': 678,
#  'đọc': 679,
#  'củ': 680,
#  'vắng': 681,
#  'lí': 682,
#  'đùi': 683,
#  'tan': 684,
#  'phát': 685,
#  'chấp': 686,
#  'quanh': 687,
#  'free': 688,
#  'lẫn': 689,
#  '15k': 690,
#  'đắng': 691,
#  'luộc': 692,
#  'sầu': 693,
#  'hòa': 694,
#  'động': 695,
#  'ghi': 696,
#  'trải': 697,
#  'khỏi': 698,
#  'phomai': 699,
#  'rượu': 700,
#  'thiệu': 701,
#  'đỉnh': 702,
#  'bạc': 703,
#  '20': 704,
#  'cúng': 705,
#  'gửi': 706,
#  'cắt': 707,
#  'nguyễn': 708,
#  'đề': 709,
#  'xuyên': 710,
#  'thoảng': 711,
#  'ngô': 712,
#  'lọc': 713,
#  'mồm': 714,
#  'riêu': 715,
#  'quyết': 716,
#  'chai': 717,
#  'rủ': 718,
#  'sụn': 719,
#  'chúng': 720,
#  'đôi': 721,
#  'socola': 722,
#  'lợn': 723,
#  'thui': 724,
#  'xương': 725,
#  'khai': 726,
#  'nở': 727,
#  'trưng': 728,
#  'bạch': 729,
#  'cũ': 730,
#  'ta': 731,
#  'có': 732,
#  'an': 733,
#  'bật': 734,
#  'bùi': 735,
#  'ly': 736,
#  'chuột': 737,
#  'tố': 738,
#  'thu': 739,
#  'câu': 740,
#  'sớm': 741,
#  'ngã': 742,
#  'hn': 743,
#  'bông': 744,
#  'chuối': 745,
#  '❤️': 746,
#  'vặt': 747,
#  'phú': 748,
#  'j': 749,
#  'lạc': 750,
#  'đũa': 751,
#  '60k': 752,
#  'leo': 753,
#  'đừng': 754,
#  'hút': 755,
#  'chuyển': 756,
#  'hnay': 757,
#  'đổ': 758,
#  'ô': 759,
#  'khủng': 760,
#  'giản': 761,
#  'chí': 762,
#  'quán': 763,
#  'chiếc': 764,
#  'lễ': 765,
#  'tanh': 766,
#  'phía': 767,
#  'nhầm': 768,
#  'đựng': 769,
#  'niềm': 770,
#  'tế': 771,
#  'bù': 772,
#  'thang': 773,
#  'gái': 774,
#  'tin': 775,
#  'giữ': 776,
#  'ruốc': 777,
#  'mọc': 778,
#  'nhiêu': 779,
#  'bây': 780,
#  'cam': 781,
#  'tỏi': 782,
#  'bề': 783,
#  'me': 784,
#  'gió': 785,
#  'báo': 786,
#  'ngắm': 787,
#  'mk': 788,
#  '5k': 789,
#  'thống': 790,
#  'nhẽo': 791,
#  'toán': 792,
#  'phép': 793,
#  'trc': 794,
#  'nhúng': 795,
#  'bí': 796,
#  'chảo': 797,
#  'xưa': 798,
#  'gặp': 799,
#  'á': 800,
#  'ồn': 801,
#  'buồn': 802,
#  'mẻ': 803,
#  '50': 804,
#  'ôi': 805,
#  'in': 806,
#  'and': 807,
#  'xay': 808,
#  'sẵn': 809,
#  'lang': 810,
#  'xứng': 811,
#  'trai': 812,
#  'heo': 813,
#  'dở': 814,
#  'nêm': 815,
#  'huế': 816,
#  '100k': 817,
#  'thìa': 818,
#  'tinh': 819,
#  'ngan': 820,
#  'măng': 821,
#  'đảm': 822,
#  'chợ': 823,
#  'dâu': 824,
#  'trái': 825,
#  'chương': 826,
#  'ảo': 827,
#  'quảng': 828,
#  'dứa': 829,
#  'chát': 830,
#  'cười': 831,
#  'dồi': 832,
#  'hihi': 833,
#  'dụng': 834,
#  'tạo': 835,
#  'da': 836,
#  'bẩn': 837,
#  'súp': 838,
#  'caramen': 839,
#  'lun': 840,
#  'nhắc': 841,
#  'tok': 842,
#  '9': 843,
#  'mình': 844,
#  'mn': 845,
#  'thiết': 846,
#  'long': 847,
#  'sách': 848,
#  'thú': 849,
#  'xích': 850,
#  'đứng': 851,
#  'quầy': 852,
#  'xá': 853,
#  'trâu': 854,
#  '😍': 855,
#  'bt': 856,
#  'nhựa': 857,
#  'gạo': 858,
#  'xét': 859,
#  'xếp': 860,
#  'cốm': 861,
#  'chạy': 862,
#  'biến': 863,
#  'viết': 864,
#  'phụ': 865,
#  'ngán': 866,
#  'máy': 867,
#  'bở': 868,
#  'tụ': 869,
#  'là': 870,
#  'cấp': 871,
#  'truyền': 872,
#  'mã': 873,
#  'nhậu': 874,
#  'gọn': 875,
#  'áp': 876,
#  'oke': 877,
#  'mại': 878,
#  'xèo': 879,
#  'mịn': 880,
#  'rẽ': 881,
#  'ú': 882,
#  'ụ': 883,
#  'mắc': 884,
#  'điện': 885,
#  'lan': 886,
#  'kho': 887,
#  'ghê': 888,
#  'sân': 889,
#  'chảy': 890,
#  'bê': 891,
#  'tổ': 892,
#  'dính': 893,
#  'quốc': 894,
#  'huhu': 895,
#  'hôi': 896,
#  'tớ': 897,
#  'ếch': 898,
#  'thông': 899,
#  'hướng': 900,
#  'bởi': 901,
#  'ngang': 902,
#  'hẹn': 903,
#  'đèn': 904,
#  'ch': 905,
#  'thuộc': 906,
#  'recommend': 907,
#  'tủ': 908,
#  'hiệu': 909,
#  '45k': 910,
#  'cố': 911,
#  'dám': 912,
#  'ngập': 913,
#  'lỗi': 914,
#  'nhg': 915,
#  'đợt': 916,
#  'bước': 917,
#  'dạo': 918,
#  'mít': 919,
#  'lắc': 920,
#  'bít': 921,
#  'hầu': 922,
#  'nhờ': 923,
#  'kĩ': 924,
#  'trở': 925,
#  'vặn': 926,
#  'tóm': 927,
#  'liệu': 928,
#  'đoạn': 929,
#  'mời': 930,
#  'bắp': 931,
#  'chim': 932,
#  'cánh': 933,
#  'sushi': 934,
#  'cắn': 935,
#  'quế': 936,
#  'mò': 937,
#  'sức': 938,
#  'kính': 939,
#  'sát': 940,
#  'ngao': 941,
#  'cũng': 942,
#  'check': 943,
#  'ty': 944,
#  'khói': 945,
#  'bbq': 946,
#  'ơn': 947,
#  'shipper': 948,
#  'nhai': 949,
#  'kêu': 950,
#  'cảo': 951,
#  'ẩm': 952,
#  'dắt': 953,
#  'tiếc': 954,
#  '80k': 955,
#  'đêm': 956,
#  'chồng': 957,
#  'lèo': 958,
#  'quản': 959,
#  'triệu': 960,
#  'tuổi': 961,
#  'chén': 962,
#  'chảnh': 963,
#  'xì': 964,
#  'kiến': 965,
#  'ong': 966,
#  'nếm': 967,
#  '15': 968,
#  'cuộn': 969,
#  'chục': 970,
#  'tăng': 971,
#  'phớ': 972,
#  'đời': 973,
#  'lát': 974,
#  'loãng': 975,
#  'giải': 976,
#  'phẩm': 977,
#  'đế': 978,
#  'thỉnh': 979,
#  'muộn': 980,
#  'hầm': 981,
#  'bưởi': 982,
#  'thì': 983,
#  'đãng': 984,
#  'ưu': 985,
#  'thi': 986,
#  'nát': 987,
#  'bổ': 988,
#  'hoá': 989,
#  'linh': 990,
#  '200k': 991,
#  '👍': 992,
#  'ruột': 993,
#  'chia': 994,
#  'tiệm': 995,
#  'nắng': 996,
#  'nhỉ': 997,
#  'kéo': 998,
#  'liền': 999,
#  'sánh': 1000,
#  ...}

# %%
len(WordIndex)
# Out:
# 13144

# %%
def embeddingsMatrix(word_index):
    embedding_matrix = np.zeros((len(word_index) + 1, 300))  
    for word, i in word_index.items():
        if i >= max_features: continue  #bỏ các ký tự có value lớn hơn max_features
        if word in w2v_model: 
            embedding_vector = w2v_model[word]
        else:
            embedding_vector = np.zeros(300,)

        embedding_matrix[i] = embedding_vector
    return embedding_matrix

matrix = embeddingsMatrix(WordIndex)

# %%
matrix.shape
# Out:
# (13145, 300)

# %%
from keras.layers import Dense, Input, LSTM, Embedding, Dropout, Activation, Conv1D, GRU 
from keras.layers import Bidirectional, GlobalMaxPooling1D, Concatenate, SpatialDropout1D 
from keras.models import Model, Sequential 
from keras import initializers, regularizers, constraints, optimizers, layers 
from tensorflow import keras 
from numpy import argmax 
from tensorflow.keras.layers import BatchNormalization 
nmodel = Sequential() 
nmodel.add(layers.Embedding(len(WordIndex) + 1, embed_size, weights=[matrix], input_length=max_len)) 
nmodel.add(SpatialDropout1D(0.5)) 
nmodel.add(Bidirectional(LSTM(64, return_sequences=True))) 
nmodel.add(layers.GlobalMaxPool1D()) 
nmodel.add(layers.Dense(10)) 
nmodel.add(BatchNormalization()) 
nmodel.add(Activation('relu')) 
nmodel.add(Dropout(0.5)) 
nmodel.add(layers.Dense(1, activation='sigmoid')) 
nmodel.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy']) 
nmodel.summary()
# Out:
# 2022-12-13 09:42:26.274681: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 30, 300)           3943500
# _________________________________________________________________
# spatial_dropout1d (SpatialDr (None, 30, 300)           0
# _________________________________________________________________
# bidirectional (Bidirectional (None, 30, 128)           186880
# _________________________________________________________________
# global_max_pooling1d (Global (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 10)                1290
# _________________________________________________________________
# batch_normalization (BatchNo (None, 10)                40
# _________________________________________________________________
# activation (Activation)      (None, 10)                0
# _________________________________________________________________
# dropout (Dropout)            (None, 10)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 4,131,721
# Trainable params: 4,131,701
# Non-trainable params: 20
# _________________________________________________________________

# %%
numepochs = 10    
batchsize = 8
h2 = nmodel.fit(Train_X, Train_y, batch_size = batchsize, epochs = numepochs, validation_data=(Val_X, Val_y))
# Out:
# Epoch 1/10
# 2022-12-13 09:42:27.058097: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# 1021/1021 [==============================] - 67s 61ms/step - loss: 0.5580 - accuracy: 0.7427 - val_loss: 0.3913 - val_accuracy: 0.8302
# Epoch 2/10
# 1021/1021 [==============================] - 62s 60ms/step - loss: 0.4403 - accuracy: 0.8057 - val_loss: 0.3574 - val_accuracy: 0.8512
# Epoch 3/10
# 1021/1021 [==============================] - 61s 60ms/step - loss: 0.4122 - accuracy: 0.8204 - val_loss: 0.3258 - val_accuracy: 0.8666
# Epoch 4/10
# 1021/1021 [==============================] - 61s 60ms/step - loss: 0.3937 - accuracy: 0.8308 - val_loss: 0.3241 - val_accuracy: 0.8644
# Epoch 5/10
# 1021/1021 [==============================] - 61s 60ms/step - loss: 0.3817 - accuracy: 0.8339 - val_loss: 0.3120 - val_accuracy: 0.8743
# Epoch 6/10
# 1021/1021 [==============================] - 62s 60ms/step - loss: 0.3598 - accuracy: 0.8494 - val_loss: 0.3019 - val_accuracy: 0.8831
# Epoch 7/10
# 1021/1021 [==============================] - 60s 59ms/step - loss: 0.3535 - accuracy: 0.8488 - val_loss: 0.3018 - val_accuracy: 0.8853
# Epoch 8/10
# 1021/1021 [==============================] - 61s 60ms/step - loss: 0.3368 - accuracy: 0.8579 - val_loss: 0.2999 - val_accuracy: 0.8875
# Epoch 9/10
# 1021/1021 [==============================] - 61s 60ms/step - loss: 0.3379 - accuracy: 0.8607 - val_loss: 0.3000 - val_accuracy: 0.8820
# Epoch 10/10
# 1021/1021 [==============================] - 61s 60ms/step - loss: 0.3289 - accuracy: 0.8639 - val_loss: 0.2907 - val_accuracy: 0.8798

# %%
testData
# Out:
#       Unnamed: 0    RevId    UserId  \
# 0              0   781115   1326532
# 1              1  1219481    422306
# 2              2  1703765   9779143
# 3              3  4870346  12924388
# 4              4  2638711   1134279
# ...          ...      ...       ...
# 5098        5098  1025826    132889
# 5099        5099  1278470   1691594
# 5100        5100  2565212   9989615
# 5101        5101  3766155  17686862
# 5102        5102  1070891   1141468
#
#                                                 Comment  \
# 0     Trà táo 35k\nCookie socola 38k \nNước ở đây bì...
# 1     Hôm rồi trung tâm mình tổ chức noel party ở đâ...
# 2     Thịt gà của quán là nhất đấy. Đi ăn gọi liền 4...
# 3     Hai đứa ăn xong đau bụng cả ngày\nChân gà ok n...
# 4     Mình vừa thử trưa nay. Điểm cộng đầu tiên là b...
# ...                                                 ...
# 5098  Bún riêu ở đây ngon mà, lúc nào cũng đông, thế...
# 5099  Quán ngồi thoải mái và cưc thích ❤ menu đa dạn...
# 5100  Quá thất vọng, chất lượng sản phẩm ngày càng đ...
# 5101  Giao hàng nhanh,  miếng băm chả đều ngon ko bị...
# 5102  Nhìn ở bên ngoài trông quán khá bé nhưng vào t...
#
#                                              image_urls
# 0     ['https://images.foody.vn/res/g8/73091/s800/fo...
# 1     ['https://images.foody.vn/res/g1/33/s800/foody...
# 2     ['https://images.foody.vn/res/g66/659655/s800/...
# 3     ['https://images.foody.vn/res/g78/772244/s800/...
# 4     ['https://images.foody.vn/res/g74/737874/s800/...
# ...                                                 ...
# 5098  ['https://images.foody.vn/res/g10/92649/s800/f...
# 5099  ['https://images.foody.vn/res/g25/247296/s800/...
# 5100  ['https://images.foody.vn/res/g89/888154/s800/...
# 5101  ['https://images.foody.vn/res/g13/128194/s800/...
# 5102  ['https://images.foody.vn/res/g29/280391/s800/...
#
# [5103 rows x 5 columns]

# %%
import sklearn.metrics as metrics
def bestThresh(Val_y, pred_val_y, pr, minthresh, maxthresh): 
    best_threshhold = 0
    bestacc = 0
    for thresh in np.arange(minthresh, maxthresh, 0.01):
        thresh = np.round(thresh, 2)
        acc = metrics.accuracy_score(Val_y, (pred_val_y>thresh).astype(int))
        if pr: print("Accuracy score for threshold {0} is {1}".format(thresh,acc))
        if(acc > bestacc): 
            best_threshhold = thresh
            bestacc = acc
    print("")
    print("Highest accuracy score is {} and the threshold is {}".format(bestacc, best_threshhold))
    return best_threshhold, bestacc

# %%
pred_val = nmodel.predict([Val_X], batch_size= batchsize, verbose=1)
bestthresh, bestacc = bestThresh(Val_y, pred_val, True, 0.1, 0.9)
pred1 = (nmodel.predict([Test_X], batch_size= batchsize, verbose=1) > bestthresh).astype(int)
# Out:
# 114/114 [==============================] - 3s 15ms/step
# Accuracy score for threshold 0.1 is 0.8324145534729879
# Accuracy score for threshold 0.11 is 0.836824696802646
# Accuracy score for threshold 0.12 is 0.836824696802646
# Accuracy score for threshold 0.13 is 0.8401323042998897
# Accuracy score for threshold 0.14 is 0.8467475192943771
# Accuracy score for threshold 0.15 is 0.8467475192943771
# Accuracy score for threshold 0.16 is 0.8478500551267916
# Accuracy score for threshold 0.17 is 0.8500551267916208
# Accuracy score for threshold 0.18 is 0.8522601984564498
# Accuracy score for threshold 0.19 is 0.8522601984564498
# Accuracy score for threshold 0.2 is 0.856670341786108
# Accuracy score for threshold 0.21 is 0.8610804851157663
# Accuracy score for threshold 0.22 is 0.8654906284454245
# Accuracy score for threshold 0.23 is 0.8654906284454245
# Accuracy score for threshold 0.24 is 0.8665931642778391
# Accuracy score for threshold 0.25 is 0.8676957001102535
# Accuracy score for threshold 0.26 is 0.8676957001102535
# Accuracy score for threshold 0.27 is 0.8710033076074972
# Accuracy score for threshold 0.28 is 0.8721058434399118
# Accuracy score for threshold 0.29 is 0.8743109151047409
# Accuracy score for threshold 0.3 is 0.8732083792723263
# Accuracy score for threshold 0.31 is 0.8743109151047409
# Accuracy score for threshold 0.32 is 0.8743109151047409
# Accuracy score for threshold 0.33 is 0.8754134509371555
# Accuracy score for threshold 0.34 is 0.8754134509371555
# Accuracy score for threshold 0.35 is 0.87651598676957
# Accuracy score for threshold 0.36 is 0.8776185226019846
# Accuracy score for threshold 0.37 is 0.8798235942668137
# Accuracy score for threshold 0.38 is 0.8809261300992283
# Accuracy score for threshold 0.39 is 0.8820286659316428
# Accuracy score for threshold 0.4 is 0.8842337375964718
# Accuracy score for threshold 0.41 is 0.886438809261301
# Accuracy score for threshold 0.42 is 0.8842337375964718
# Accuracy score for threshold 0.43 is 0.886438809261301
# Accuracy score for threshold 0.44 is 0.8842337375964718
# Accuracy score for threshold 0.45 is 0.8853362734288864
# Accuracy score for threshold 0.46 is 0.8853362734288864
# Accuracy score for threshold 0.47 is 0.8831312017640573
# Accuracy score for threshold 0.48 is 0.8820286659316428
# Accuracy score for threshold 0.49 is 0.8798235942668137
# Accuracy score for threshold 0.5 is 0.8798235942668137
# Accuracy score for threshold 0.51 is 0.8798235942668137
# Accuracy score for threshold 0.52 is 0.8798235942668137
# Accuracy score for threshold 0.53 is 0.8853362734288864
# Accuracy score for threshold 0.54 is 0.8875413450937155
# Accuracy score for threshold 0.55 is 0.886438809261301
# Accuracy score for threshold 0.56 is 0.8886438809261301
# Accuracy score for threshold 0.57 is 0.886438809261301
# Accuracy score for threshold 0.58 is 0.8875413450937155
# Accuracy score for threshold 0.59 is 0.8853362734288864
# Accuracy score for threshold 0.6 is 0.8842337375964718
# Accuracy score for threshold 0.61 is 0.8842337375964718
# Accuracy score for threshold 0.62 is 0.8842337375964718
# Accuracy score for threshold 0.63 is 0.8820286659316428
# Accuracy score for threshold 0.64 is 0.8820286659316428
# Accuracy score for threshold 0.65 is 0.8809261300992283
# Accuracy score for threshold 0.66 is 0.8809261300992283
# Accuracy score for threshold 0.67 is 0.8820286659316428
# Accuracy score for threshold 0.68 is 0.8809261300992283
# Accuracy score for threshold 0.69 is 0.8787210584343991
# Accuracy score for threshold 0.7 is 0.8754134509371555
# Accuracy score for threshold 0.71 is 0.8721058434399118
# Accuracy score for threshold 0.72 is 0.8721058434399118
# Accuracy score for threshold 0.73 is 0.8676957001102535
# Accuracy score for threshold 0.74 is 0.8654906284454245
# Accuracy score for threshold 0.75 is 0.856670341786108
# Accuracy score for threshold 0.76 is 0.8467475192943771
# Accuracy score for threshold 0.77 is 0.8434399117971334
# Accuracy score for threshold 0.78 is 0.8335170893054025
# Accuracy score for threshold 0.79 is 0.8291069459757442
# Accuracy score for threshold 0.8 is 0.8224917309812569
# Accuracy score for threshold 0.81 is 0.8180815876515987
# Accuracy score for threshold 0.82 is 0.814773980154355
# Accuracy score for threshold 0.83 is 0.8103638368246968
# Accuracy score for threshold 0.84 is 0.8081587651598677
# Accuracy score for threshold 0.85 is 0.8004410143329658
# Accuracy score for threshold 0.86 is 0.7916207276736494
# Accuracy score for threshold 0.87 is 0.7794928335170893
# Accuracy score for threshold 0.88 is 0.7750826901874311
# Accuracy score for threshold 0.89 is 0.7695700110253583
#
# Highest accuracy score is 0.8886438809261301 and the threshold is 0.56
# 638/638 [==============================] - 6s 10ms/step

# %%
out_df1 = pd.DataFrame({"RevId":testData["RevId"].values})
out_df1['Rating'] = pred1
out_df1.to_csv("resultX.csv", index=False)
out_df1
# Out:
#         RevId  Rating
# 0      781115       1
# 1     1219481       1
# 2     1703765       1
# 3     4870346       1
# 4     2638711       1
# ...       ...     ...
# 5098  1025826       1
# 5099  1278470       1
# 5100  2565212       0
# 5101  3766155       1
# 5102  1070891       1
#
# [5103 rows x 2 columns]

# %%
count0 = 0
count1 = 0
for i in pred1:
    if i == 1: count1 += 1
    else: count0 += 1
print(count1)
print(count0)
# Out:
# 4101
# 1002
